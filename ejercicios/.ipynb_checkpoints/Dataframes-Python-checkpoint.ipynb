# %% [markdown]
# # Dataframes

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Creación DataFrame

# %%
nombres = np.array(["Carlos", "Eduardo", "Andrea"])
apellidos = np.array(["Meneses", "Franco", "Lopez"])

# %%
data = pd.DataFrame({"nombres":nombres, "apellidos":apellidos})

# %%
data
# Out:
#    nombres apellidos
# 0   Carlos   Meneses
# 1  Eduardo    Franco
# 2   Andrea     Lopez

# %%
letras = ["A", "B", "C"]
data1 = pd.DataFrame({"Valor-1": np.random.randint(1, 10, 10), "Valor-2": np.random.randint(1, 10, 10), "Key": np.random.choice(letras, 10)})
data1
# Out:
#    Valor-1  Valor-2 Key
# 0        9        5   A
# 1        4        1   C
# 2        2        3   A
# 3        4        7   C
# 4        6        8   A
# 5        2        5   A
# 6        9        6   B
# 7        2        5   C
# 8        5        3   C
# 9        5        8   B

# %% [markdown]
# ## Agregados

# %%
data1.groupby("Key")["Valor-1"].aggregate(suma=sum, minimo=np.min, media=np.mean, maximo=np.max, 
                                          mediana=np.median, std=np.std, varianza=np.var)
# Out:
#      suma  minimo  media  maximo  mediana       std   varianza
# Key
# A      19       2   4.75       9        4  3.403430  11.583333
# B      14       5   7.00       9        7  2.828427   8.000000
# C      15       2   3.75       5        4  1.258306   1.583333

# %%
data1.groupby("Key").agg([sum, np.min, np.mean, np.max])
# Out:
#     Valor-1                 Valor-2
#         sum amin  mean amax     sum amin  mean amax
# Key
# A        19    2  4.75    9      21    3  5.25    8
# B        14    5  7.00    9      14    6  7.00    8
# C        15    2  3.75    5      16    1  4.00    7

# %% [markdown]
# ## Carga DataFrame `bodyfat`

# %%
bodyfat = pd.read_csv("../data/bodyfat.txt", delimiter=" ", decimal=".", encoding="utf-8")

# %%
bodyfat.keys()
# Out:
# Index(['Density', 'Fat', 'Age', 'Weight', 'Height', 'Neck', 'Chest', 'Abdomen',
#        'Hip', 'Thigh', 'Knee', 'Ankle', 'Biceps', 'Forearm', 'Wrist'],
#       dtype='object')

# %%
bodyfat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 252 entries, 1 to 252
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Density  252 non-null    float64
#  1   Fat      252 non-null    float64
#  2   Age      252 non-null    int64
#  3   Weight   252 non-null    float64
#  4   Height   252 non-null    float64
#  5   Neck     252 non-null    float64
#  6   Chest    252 non-null    float64
#  7   Abdomen  252 non-null    float64
#  8   Hip      252 non-null    float64
#  9   Thigh    252 non-null    float64
#  10  Knee     252 non-null    float64
#  11  Ankle    252 non-null    float64
#  12  Biceps   252 non-null    float64
#  13  Forearm  252 non-null    float64
#  14  Wrist    252 non-null    float64
# dtypes: float64(14), int64(1)
# memory usage: 31.5 KB

# %%
bodyfat.head(8)
# Out:
#    Density   Fat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 1   1.0708  12.3   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0
# 2   1.0853   6.1   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7
# 3   1.0414  25.3   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6
# 4   1.0751  10.4   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1
# 5   1.0340  28.7   24  184.25   71.25  34.4   97.3    100.0  101.9   63.2
# 6   1.0502  20.9   24  210.25   74.75  39.0  104.5     94.4  107.8   66.0
# 7   1.0549  19.2   26  181.00   69.75  36.4  105.1     90.7  100.3   58.4
# 8   1.0704  12.4   25  176.00   72.50  37.8   99.6     88.5   97.1   60.0
#
#    Knee  Ankle  Biceps  Forearm  Wrist
# 1  37.3   21.9    32.0     27.4   17.1
# 2  37.3   23.4    30.5     28.9   18.2
# 3  38.9   24.0    28.8     25.2   16.6
# 4  37.3   22.8    32.4     29.4   18.2
# 5  42.2   24.0    32.2     27.7   17.7
# 6  42.0   25.6    35.7     30.6   18.8
# ...

# %% [markdown]
# ## Filtracion de subconjuntos

# %% [markdown]
# Mostrar la primera fila del dataframe y las columnas `Density` y `Neck`

# %%
bodyfat[0:1][["Density", "Neck"]]
# Out:
#    Density  Neck
# 1   1.0708  36.2

# %%
bodyfat.iloc[[0],:]
# Out:
#    Density   Fat  Age  Weight  Height  Neck  Chest  Abdomen   Hip  Thigh  \
# 1   1.0708  12.3   23  154.25   67.75  36.2   93.1     85.2  94.5   59.0
#
#    Knee  Ankle  Biceps  Forearm  Wrist
# 1  37.3   21.9    32.0     27.4   17.1

# %%
bodyfat.loc[:1, ["Density", "Neck"]]
# Out:
#    Density  Neck
# 1   1.0708  36.2

# %% [markdown]
# Mostrar las columnas Abdomen y Fat de los individuos que tienen el largo del abdomen mayor o igual a 120

# %%
bodyfat[bodyfat.Abdomen >= 120][["Abdomen", "Fat"]]
# Out:
#      Abdomen   Fat
# 39     148.1  35.2
# 41     126.2  34.5
# 216    122.1  47.5

# %%
bodyfat.loc[bodyfat.Abdomen >= 120, ["Abdomen", "Fat"]]
# Out:
#      Abdomen   Fat
# 39     148.1  35.2
# 41     126.2  34.5
# 216    122.1  47.5

# %% [markdown]
# Mostrar a los mayores o iguales de 35 años y que tengan el largo del cuello menor o igual a 33

# %%
bodyfat[(bodyfat.Age >= 35) & (bodyfat.Neck <= 33)]
# Out:
#      Density   Fat  Age  Weight  Height  Neck  Chest  Abdomen   Hip  Thigh  \
# 45    1.0814   7.7   39  125.25    68.0  31.5   85.1     76.0  88.2   50.0
# 49    1.0678  13.6   45  135.75    68.5  32.8   92.3     83.4  90.4   52.0
# 106   1.0578  18.0   43  165.50    68.5  31.1   93.1     87.3  96.6   54.7
#
#      Knee  Ankle  Biceps  Forearm  Wrist
# 45   34.7   21.0    26.1     23.1   16.1
# 49   35.8   20.6    28.8     25.5   16.3
# 106  39.0   24.8    31.0     29.4   18.8

# %%
bodyfat.loc[(bodyfat.Age >= 35) & (bodyfat.Neck <= 33), ["Density", "Fat"]]
# Out:
#      Density   Fat
# 45    1.0814   7.7
# 49    1.0678  13.6
# 106   1.0578  18.0

# %% [markdown]
# Calcular los estadisticos de resumen de las variables cuantitativas

# %%
bodyfat.describe()
# Out:
#           Density         Fat         Age      Weight      Height        Neck  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000  252.000000
# mean     1.055574   19.150794   44.884921  178.924405   70.148810   37.992063
# std      0.019031    8.368740   12.602040   29.389160    3.662856    2.430913
# min      0.995000    0.000000   22.000000  118.500000   29.500000   31.100000
# 25%      1.041400   12.475000   35.750000  159.000000   68.250000   36.400000
# 50%      1.054900   19.200000   43.000000  176.500000   70.000000   38.000000
# 75%      1.070400   25.300000   54.000000  197.000000   72.250000   39.425000
# max      1.108900   47.500000   81.000000  363.150000   77.750000   51.200000
#
#             Chest     Abdomen         Hip       Thigh        Knee       Ankle  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000  252.000000
# mean   100.824206   92.555952   99.904762   59.405952   38.590476   23.102381
# ...

# %% [markdown]
# Hacer un Histograma de todas las variables del Dataframe

# %%
import matplotlib.pyplot as plt
bodyfat.hist(bins=20, figsize=(20,15))
plt.show()

# %% [markdown]
# ## Carga DataFrame `Medals`

# %%
medals = pd.read_csv("../data/medals.csv", decimal=".", encoding="utf-8")

# %%
medals.head()
# Out:
#    Year      City       Sport      Discipline  NOC       Event Event gender  \
# 0  1924  Chamonix     Skating  Figure skating  AUT  individual            M
# 1  1924  Chamonix     Skating  Figure skating  AUT  individual            W
# 2  1924  Chamonix     Skating  Figure skating  AUT       pairs            X
# 3  1924  Chamonix   Bobsleigh       Bobsleigh  BEL    four-man            M
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  CAN  ice hockey            M
#
#     Medal
# 0  Silver
# 1    Gold
# 2    Gold
# 3  Bronze
# 4    Gold

# %%
medals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2311 entries, 0 to 2310
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Year          2311 non-null   int64
#  1   City          2311 non-null   object
#  2   Sport         2311 non-null   object
#  3   Discipline    2311 non-null   object
#  4   NOC           2311 non-null   object
#  5   Event         2311 non-null   object
#  6   Event gender  2311 non-null   object
#  7   Medal         2311 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 144.6+ KB

# %%
import numpy as np
np.random.seed(1201)
muestra = np.random.randint(0, 2311, 10)
muestra = np.sort(muestra)
medals.iloc[muestra]
# Out:
#       Year                    City     Sport       Discipline  NOC  \
# 65    1928              St. Moritz   Skating    Speed skating  NOR
# 101   1932             Lake Placid    Skiing  Cross Country S  FIN
# 153   1936  Garmisch-Partenkirchen   Skating   Figure skating  HUN
# 474   1964               Innsbruck      Luge             Luge  AUT
# 1070  1984                Sarajevo    Skiing  Cross Country S  NOR
# 1572  1994             Lillehammer   Skating   Figure skating  RUS
# 1766  1998                  Nagano    Skiing    Alpine Skiing  NOR
# 2052  2002          Salt Lake City    Skiing   Freestyle Ski.  USA
# 2151  2006                   Turin  Biathlon         Biathlon  GER
# 2293  2006                   Turin   Skating   Short Track S.  USA
#
#              Event Event gender   Medal
# 65           5000m            M  Bronze
# 101           50km            M  Silver
# 153          pairs            X  Bronze
# 474        singles            W  Bronze
# ...

# %% [markdown]
# ## Carga DataFrame `Titanic`

# %%
titanic = pd.read_csv("../data/titanic.csv")

# %%
titanic.shape
# Out:
# (1313, 6)

# %%
titanic.head()
# Out:
#                                             Name PClass    Age     Sex  \
# 0                   Allen, Miss Elisabeth Walton    1st  29.00  female
# 1                    Allison, Miss Helen Loraine    1st   2.00  female
# 2            Allison, Mr Hudson Joshua Creighton    1st  30.00    male
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 4                  Allison, Master Hudson Trevor    1st   0.92    male
#
#    Survived  SexCode
# 0         1        1
# 1         0        1
# 2         0        0
# 3         0        1
# 4         1        0

# %% [markdown]
# ## Reemplazar valores `NaN` por la media

# %%
edad_media = np.round(np.mean(titanic.Age),0)
titanic["Age"].fillna(edad_media, inplace=True)

# %%
np.random.seed(12512)
muestra = np.random.randint(0, 1313, 10)
muestra = np.sort(muestra)
titanic.iloc[muestra]
# Out:
#                                     Name PClass   Age     Sex  Survived  \
# 120         Gracie, Colonel Archibald IV    1st  54.0    male         1
# 215                Rothschild, Mr Martin    1st  55.0    male         0
# 299                    Farthing, Mr John    1st  30.0    male         0
# 348     Brown, Mr Thomas William Solomon    2nd  45.0    male         0
# 717                       Chip, Mr Chang    3rd  32.0    male         0
# 786                    Econovic, Mr Joso    3rd  30.0    male         0
# 881                Jensen, Mr Hans Peder    3rd  20.0    male         0
# 973             Lobb, Mrs William Arthur    3rd  30.0  female         0
# 1142                 Reynolds, Mr Harold    3rd  30.0    male         0
# 1267  Van Billiard, Master James William    3rd  30.0    male         0
#
#       SexCode
# 120         0
# 215         0
# 299         0
# 348         0
# 717         0
# 786         0
# 881         0
# 973         1
# 1142        0
# 1267        0

# %%
titanic.Survived.value_counts()
# Out:
# 0    863
# 1    450
# Name: Survived, dtype: int64

# %%
titanic.shape
# Out:
# (1313, 6)

# %%
titanic[titanic.Age > 30].sort_values("Age").tail(5)
# Out:
#                                                   Name PClass   Age     Sex  \
# 73   Crosby, Mrs Edward Gifford (Catherine Elizabet...    1st  69.0  female
# 72                      Crosby, Captain Edward Gifford    1st  70.0    male
# 9                               Artagaveytia, Mr Ramon    1st  71.0    male
# 505                         Mitchell, Mr Henry Michael    2nd  71.0    male
# 119                           Goldschmidt, Mr George B    1st  71.0    male
#
#      Survived  SexCode
# 73          1        1
# 72          0        0
# 9           0        0
# 505         0        0
# 119         0        0

# %% [markdown]
# ## Eliminar Duplicados
#
# Elimina elementos duplicados según el parametro `Name`

# %%
titanic_dupl = titanic.drop_duplicates(subset="Name")
titanic_dupl.shape[0]
# Out:
# 1310

# %% [markdown]
# ## GroupBy

# %% [markdown]
# Mostrar los individuos que sobrevivieron y no sobrevivieron en el Titanic

# %%
titanic.groupby("Survived")["Name"].count()
# Out:
# Survived
# 0    863
# 1    450
# Name: Name, dtype: int64

# %% [markdown]
# Calcular la media de la edad de los individuos agrupadas por el Sexo y si sobrevivieron o no

# %%
np.round(titanic.groupby(["Sex", "Survived"])["Age"].mean(),2)
# Out:
# Sex     Survived
# female  0           27.65
#         1           30.61
# male    0           31.22
#         1           27.26
# Name: Age, dtype: float64

# %% [markdown]
# Mostrar los estadísticos de resumen de la Edad de los pasajeros del Titanic agrupados por el género

# %%
titanic.groupby("Sex").agg(minimo=("Age", np.min), 
                           media=("Age", np.mean), 
                           maximo=("Age", np.max),
                           mediana=("Age", np.median),
                           std=("Age", np.std),
                           varianza=("Age", np.var))
# Out:
#         minimo      media  maximo  mediana        std    varianza
# Sex
# female    0.17  29.623745    69.0     30.0  11.655012  135.839315
# male      0.33  30.557826    71.0     30.0  10.328406  106.675962
